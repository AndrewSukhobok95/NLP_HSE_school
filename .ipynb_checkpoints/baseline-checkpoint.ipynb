# %% [markdown]
# # NLP HSE School

# %%
from pymystem3 import Mystem
import pandas as pd
import re

# %% [markdown]
# Перенесем словарь РуСентиЛекс в DataFrame.

# %%
with open('RuSentiLex2017_revised_2utf.txt', 'r') as f:
    dict_rsl = f.readlines()
dict_rsl = pd.DataFrame(
    [string.split(',') for string in dict_rsl[18:]],
    columns=['word', 'part_of_speech', 'lemma', 'sentiment', 'source', 'ambiguity', 'smth1', 'smth2']
)

# %%
def sentiment_calc(obj):
    obj = obj.replace(' ', '')
    if obj == 'positive':
        return 1
    elif obj == 'negative':
        return -1
    else:
        return 0

# %%
dict_rsl['sentiment'] = dict_rsl['sentiment'].apply(sentiment_calc)

# %%
dict_compar = dict_rsl[['lemma', 'sentiment']].copy()

# %%
vals = dict_compar['lemma'].values.tolist()
dict_compar_ = dict_compar[['sentiment']].copy()
dict_compar_.index = dict_compar['lemma']
dict_compar_map = dict_compar_.to_dict()['sentiment']

# %% [markdown]
# Собираем нужные файлы

# %%
# Функция для чтения набора файлов относящихся к n статье
def art_read(num):
    with open('Texts/art{}.txt'.format(num), 'r', encoding='utf-8') as f:
        text_lines = f.readlines()
        f.seek(0)
        text_full = f.read()

    with open('Texts/art{}.opin.txt'.format(num), 'r', encoding='utf-8') as f:
        opin_lines = f.readlines()
        f.seek(0)
        opin_full = f.read()

    with open('Texts/art{}.ann'.format(num), 'r') as f:
        entities_lines = f.readlines()
        f.seek(0)
        entities_full = f.read()
    return {'txt_l':text_lines, 'txt_f':text_full, 'opin_l':opin_lines,
            'opin_f':opin_full, 'ent_l':entities_lines, 'ent_f':entities_full}

# %%
art = art_read(1)
text_lines = art['txt_l']
text_full = art['txt_f']
ent_lines = art['ent_l']
ent_full = art['ent_f']

# %% [markdown]
# Рассмотрение сущностей

# %%
def entity_transform(lemmas):
    result = ''.join(lemmas)
    result = result.replace('\n', '')
    return result

m = Mystem()

def entity_pairs(ent_lines):
    entities = pd.DataFrame(
        [
            sum([re.findall(r'T[0-9]+\t([A-Z]+)?', string) for string in ent_lines], []),
            sum([re.findall(r'[0-9]+ [0-9]+\t(.+?)\n', string) for string in ent_lines], [])
        ], index = ['type', 'name']
    ).T
    entities = entities[(entities['name']!='Author') & (entities['name']!='Unknown')].dropna().reset_index(drop=True)
    entities['name'] = entities['name'].apply(m.lemmatize)
    entities['name'] = entities['name'].apply(entity_transform)
    entities_unique = entities.drop_duplicates()
    entities_unique_list = entities_unique['name'].values.tolist()
    list_of_pairs = [(entities_unique_list[p1], entities_unique_list[p2])
                     for p1 in range(len(entities_unique_list))
                     for p2 in range(p1+1,len(entities_unique_list))]
    return list_of_pairs

list_of_pairs = entity_pairs(ent_lines)

# %%
import pandas as pd
from pymystem3 import Mystem
df = pd.DataFrame()
m=Mystem()
for i in range(1,46):
    if(i in [9,22,26]): continue
    df2 = pd.read_json('Texts/art{}syn.json'.format(i))
    df2['file'] = i
    df = pd.concat([df,df2]) 


df = df.reset_index()
def get_struct_data(x):
    sentl =[]
    pars=[]
    for text in x:
        for sent in text:
            sentl = sent.split(' ')
            to_app = [sentl[i] for i in range(len(sentl)) if i in([0,1,4,6,8,10,12])]
            to_app.append(m.lemmatize(to_app[2])[0])
            pars.append(to_app)
    return(pars)
       
df['syntax'] = df['syntax'].apply(get_struct_data)  


def get_mutual_node(n_file,row,ent1,ent1pos,ent2,ent2pos):
    syntax = (df[(df['file']==n_file) & (df['index']==row)].syntax.iloc[0])
    
    def get_node(e,p):
        e = e.split(" ")[0]
        ent_dict = dict()
        for i in range(len(syntax)):
            if(syntax[i][7]==e):
                ent_dict[abs(int(syntax[i][1])-p)]=i
        return ent_dict[sorted(ent_dict)[0]]
    def get_route(i):
        route = list()
        for _ in range(len(syntax)):
            h=int(syntax[i][5])
            if(h ==-1): return route
            route.append(syntax[h])
            i=h
    print(ent1 + ent2)
    #print(syntax)
    ent_node1 = get_node(ent1,ent1pos)
    ent_node2 = get_node(ent2,ent2pos)
    route1= get_route(ent_node1)[::-1]
    route2= get_route(ent_node2)[::-1]
    if(len(route1)==0): return syntax[ent_node1],syntax[ent_node1],syntax[ent_node2]
    if(len(route2)==0): return syntax[ent_node2],syntax[ent_node1],syntax[ent_node2]

    for i in range(len(route1)):
        #print(i)
        if(route1[i][0]==route2[i][0]): obj=route1[i]
        else: break
    
    return obj,syntax[ent_node1],syntax[ent_node2]

# %% [markdown]
# Анализ первого текста

# %%
import re
def sentance_extraction(n_row,text, pairs):
    lemmas = m.lemmatize(text)
    sentence = ''.join(lemmas)
    sentence_ent = []
    for p in pairs:
        if (p[0] in sentence) & (p[1] in sentence):
            first_char = None
            
            #print(first_char)
            second_char = None
            regex1= re.compile(r"(?![\\w\\d]){}(?![\\w\\d])".format(p[0]),flags=re.U)
            regex2= re.compile(r"(?![\\w\\d]){}(?![\\w\\d])".format(p[1]),flags=re.U)
            for first_char in [m.start(0) for m in re.finditer(regex1, sentence)]:break
            for second_char in [m.start(0) for m in re.finditer(regex2, sentence)]:break
            print(first_char)
            print(second_char)
            
            if(not first_char or not second_char): continue
            get_mutual_node(1,n_row,p[0],first_char,p[1],second_char)
            sorted_ent = sorted(
                [
                    (first_char,p[0]), (second_char, p[1])
                ],
                key = lambda element : element[0]
            )

            if sorted_ent not in sentence_ent:
                sentence_ent.append(sorted_ent)

    result = []
    for p in sentence_ent:
        if p[1][0] - p[0][0] > 10:

            words = []
            for v in vals:
                if v in sentence[p[0][0]:p[1][0]]:
                    if v not in words:
                        words.append(v)

            result.append(
                [p[0][1],
                p[1][1],
                sum(list(map(lambda x: dict_compar_map[x], words))),
                text]
            )
    return result

# %%
text_lines.remove('\n')
text_lines
df[df['file']==1]
# Out:
#     index                                             syntax  \
# 0       0  [[0, 3, СМИ, NOUN, Animacy=Inan|Case=Nom|Gende...
# 1       1  [[0, 6, inosmi, ADJ, Animacy=Inan|Case=Nom|Gen...
# 2      10  [[0, 5, Обама, NOUN, Animacy=Anim|Case=Nom|Gen...
# 3      11  [[0, 1, C, ADP, Animacy=Inan|Case=Nom|Gender=F...
# 4      12  [[0, 1, А, CONJ, fPOS=CONJ++, 7, cc, а], [2, 1...
# 5      13  [[0, 1, И, CONJ, fPOS=CONJ++, 3, cc, и], [2, 1...
# 6      14  [[0, 5, Таким, DET, Case=Ins|Gender=Masc|Numbe...
# 7      15  [[0, 2, По, ADP, fPOS=ADP++, 2, case, по], [3,...
# 8      16  [[0, 10, Изначально, ADV, Degree=Pos|fPOS=ADV+...
# 9      17  [[0, 2, По, ADP, fPOS=ADP++, 1, case, по], [3,...
# 10     18  [[0, 6, Однако, ADV, Degree=Pos|fPOS=ADV++, 10...
# 11     19  [[0, 1, В, ADP, fPOS=ADP++, 1, case, в], [2, 7...
# 12      2  [[0, 1, 5, NUM, fPOS=NUM++, -1, ROOT, 5], [1, ...
# 13     20  [[0, 1, «, PUNCT, fPOS=PUNCT++,, 1, punct, «\n...
# 14     21  [[0, 12, Беспокойство, NOUN, Animacy=Inan|Case...
# 15     22  [[0, 1, О, ADP, fPOS=ADP++, 2, case, о], [2, 1...
# 16     23  [[0, 7, Издание, NOUN, Animacy=Inan|Case=Nom|G...
# 17     24  [[0, 2, Но, CONJ, fPOS=CONJ++, 6, cc, но], [3,...
# 18     25  [[0, 7, Издание, NOUN, Animacy=Inan|Case=Nom|G...
# 19     26  [[0, 6, Однако, ADV, Degree=Pos|fPOS=ADV++, 12...
# 20     27  [[0, 6, Москва, NOUN, Animacy=Inan|Case=Nom|Ge...
# 21     28  [[0, 5, Главы, NOUN, Animacy=Anim|Case=Nom|Gen...
# 22     29  [[0, 8, Очевидно, ADJ, Degree=Pos|Gender=Neut|...
# 23      3  [[0, 5, Зачем, ADV, Degree=Pos|fPOS=ADV++, 2, ...
# 24     30  [[0, 2, До, ADP, fPOS=ADP++, 3, case, до], [3,...
# 25     31  [[0, 1, В, ADP, fPOS=ADP++, 2, case, в], [2, 7...
# 26     32  [[0, 12, Руководители, NOUN, Animacy=Anim|Case...
# 27     33  [[0, 3, При, ADP, fPOS=ADP++, 1, case, при], [...
# 28     34  [[0, 1, С, ADP, fPOS=ADP++, 2, case, с], [2, 8...
# 29     35  [[0, 1, С, ADP, fPOS=ADP++, 2, case, с], [2, 6...
# 30     36  [[0, 5, Среди, ADP, fPOS=ADP++, 1, case, среди...
# 31     37  [[0, 1, И, CONJ, fPOS=CONJ++, 4, cc, и], [2, 8...
# 32     38  [[0, 6, Keyhan, NOUN, Animacy=Inan|Case=Nom|Ge...
# 33     39  [[0, 8, Согласно, ADP, fPOS=ADP++, 2, case, со...
# 34      4  [[0, 5, 30.04, NUM, fPOS=NUM++, 2, nummod, 30....
# 35     40  [[0, 7, Аятолла, NOUN, Animacy=Inan|Case=Gen|G...
# 36     41  [[0, 1, А, CONJ, fPOS=CONJ++, 9, cc, а], [2, 3...
# 37     42  [[0, 1, В, ADP, fPOS=ADP++, 1, case, в], [2, 1...
# 38     43  [[0, 15, Инспирированные, VERB, Aspect=Perf|Ca...
# 39     44  [[0, 1, В, ADP, fPOS=ADP++, 1, case, в], [2, 7...
# 40     45  [[0, 3, Это, NOUN, Animacy=Inan|Case=Nom|Gende...
# 41     46  [[0, 1, В, ADP, fPOS=ADP++, 1, case, в], [2, 7...
# 42     47  [[0, 8, Владимир, NOUN, Animacy=Anim|Case=Nom|...
# 43     48  [[0, 3, Это, NOUN, Animacy=Inan|Case=Nom|Gende...
# 44     49  [[0, 11, Кандидатуру, NOUN, Animacy=Inan|Case=...
# 45      5  [[0, 8, Согласно, ADP, fPOS=ADP++, 1, case, со...
# 46     50  [[0, 9, Последний, ADJ, Case=Nom|Degree=Pos|Ge...
# 47     51  [[0, 6, Однако, ADV, Degree=Pos|fPOS=ADV++, 11...
# 48     52  [[0, 7, Тегеран, NOUN, Animacy=Inan|Case=Nom|G...
# 49     53  [[0, 4, Иран, NOUN, Animacy=Inan|Case=Nom|Gend...
# 50     54                                                 []
# 51      6  [[0, 6, Однако, ADV, Degree=Pos|fPOS=ADV++, 6,...
# 52      7  [[0, 8, Примерно, ADV, Degree=Pos|fPOS=ADV++, ...
# 53      8  [[0, 6, Почему, ADV, Degree=Pos|fPOS=ADV++, 19...
# 54      9  [[0, 7, Следует, VERB, Aspect=Imp|Mood=Ind|Num...
#
#                                                  text  file
# 0   СМИ Ирана: Финляндия не хочет вступать в НАТО ...     1
# 1                                           inosmi.ru     1
# 2   Обама крайне нуждается в любых шагах, которые ...     1
# 3   C другой стороны, сирийская армия при поддержк...     1
# 4   А контроль над этими провинциями — это господс...     1
# 5   И правительственная армия объявила о начале бо...     1
# 6   Таким образом, напрашивается вывод: если эти о...     1
# 7   По его мнению, на самом деле цель Белого дома ...     1
# 8   Изначально иранские СМИ сообщали об отказе Мос...     1
# 9   По соглашениям США и РФ, боевые действия в окр...     1
# 10  Однако в российском Минобороны, как и в МИДе, ...     1
# 11  В ответ на просьбы Джона Керри, который накану...     1
# 12                                         5-го, 2016     1
# 13  «Мы не можем оказывать давление на администрац...     1
# 14  Беспокойство США очевидно: тот, кто окажется п...     1
# 15  О категорическом отказе России влиять на сирий...     1
# 16  Издание, со ссылкой на срочное сообщение канал...     1
# 17  Но через пару дней тот же портал Javan (3.05) ...     1
# 18  Издание отметило, что, действительно, по мере ...     1
# 19  Однако после визита в Москву спецпосланника ОО...     1
# 20  Москва и Пекин осудили инициативы США по разме...     1
# 21  Главы дипведомств РФ и КНР на совместной пресс...     1
# 22  Очевидно, что Россия и КНР считают планы США п...     1
# 23  Зачем американцам понадобилось перебросить 250...     1
# 24  До 4 тысяч военнослужащих намерен сосредоточит...     1
# 25  В общей сложности дополнительные силы НАТО на ...     1
# 26  Руководители НАТО подчеркивают, что будут дейс...     1
# 27  При этом Москва неоднократно подчеркивала, что...     1
# 28  С другой стороны, альянс старается воплотить в...     1
# 29  С этой целью НАТО старается завлечь к себе те ...     1
# 30  Среди них особое место занимает Финляндия, для...     1
# 31  И сейчас страна не проявляет особой склонности...     1
# 32  Keyhan сообщает о докладе, подготовленном для ...     1
# 33  Согласно последним данным соцопросов, добавила...     1
# 34        30.04) Алиреза Резахах (Alireza Rezakhah).      1
# 35  Аятолла Али Хаменеи, давая оценку ирано-корейс...     1
# 36  А в целом американское влияние на политику люб...     1
# 37  В качестве примера Али Хаменеи привел ситуацию...     1
# 38  Инспирированные США и поддержанные Европой «ре...     1
# 39  В итоге перспектива военного противостояния с ...     1
# 40  Это может стать реальностью, последствия котор...     1
# 41  В канун Первомая в России произведены радикаль...     1
# 42  Владимир Путин отправил в отставку сразу семь ...     1
# 43  Это самая крупная перестановка в российских си...     1
# 44  Кандидатуру республиканца Дональда Трампа на п...     1
# 45  Согласно заявлениям из Пентагона, цель США — с...     1
# 46  Последний, отметил Алеми, наиболее откровенно ...     1
# 47  Однако, полагает Алеми, подобное замечание гла...     1
# 48  Тегеран и Дамаск — это союзники в политическом...     1
# 49  Иран и Сирия входят в одну группу квалификацио...     1
# 50                                                        1
# 51  Однако в Дамаске действия Вашингтона резко осу...     1
# 52  Примерно в аналогичном ключе высказалась и Мос...     1
# 53  Почему же и в Москве и Дамаске, которые также ...     1
# 54  Следует напомнить, указывает он, что Сирия ока...     1

# %%
text_lines = [line for line in text_lines if line != '\n']
opinions = []
for i in range(len(text_lines)):
    print("line"+str(i))
    print(text_lines[i])
    opinions += sentance_extraction(i-1,text_lines[i].replace("{Author, Unknown} ",""), list_of_pairs)
# Out:
# line0
# {Author, Unknown}
#
# line1
# {Author, Unknown} СМИ Ирана: Финляндия не хочет вступать в НАТО из страха перед Россией?
#
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# line2
# {Author, Unknown} inosmi.ru
#
# line3
# {Author, Unknown} 5-го, 2016
#
# line4
# {Author, Unknown} Зачем американцам понадобилось перебросить 250 своих военных на северо-восток Сирии, к окрестностям города Румийлан, разбирался обозреватель Khorasan (
#
# None
# None
# None
# 140
# None
# None
# None
# None
# None
# None
# None
# 140
# None
# None
# None
# None
# None
# None
# 140
# None
# 140
# None
# 140
# None
# None
# None
# None
# None
# None
# None
# line5
# {Author, Unknown} 30.04) Алиреза Резахах (Alireza Rezakhah).
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-98-5e747120099e> in <module>()
#       4     print("line"+str(i))
#       5     print(text_lines[i])
# ----> 6     opinions += sentance_extraction(i-1,text_lines[i].replace("{Author, Unknown} ",""), list_of_pairs)
#
# <ipython-input-97-3e9d41dbc540> in sentance_extraction(n_row, text, pairs)
#      10             #print(first_char)
#      11             second_char = None
# ---> 12             regex1= re.compile(r"(?![а-я\\w\\d]){}(?![а-я\\w\\d])".format(p[0]),flags=re.U)
#      13             regex2= re.compile(r"(?![а-я\\w\\d]){}(?![а-я\\w\\d])".format(p[1]),flags=re.U)
#      14             for first_char in [m.start(0) for m in re.finditer(regex1, sentence)]:break
#
# /home/tophel/anaconda3/lib/python3.6/re.py in compile(pattern, flags)
#     231 def compile(pattern, flags=0):
#     232     "Compile a regular expression pattern, returning a pattern object."
# --> 233     return _compile(pattern, flags)
#     234
#     235 def purge():
#
# /home/tophel/anaconda3/lib/python3.6/re.py in _compile(pattern, flags)
#     299     if not sre_compile.isstring(pattern):
#     300         raise TypeError("first argument must be string or compiled pattern")
# --> 301     p = sre_compile.compile(pattern, flags)
#     302     if not (flags & DEBUG):
#     303         if len(_cache) >= _MAXCACHE:
#
# /home/tophel/anaconda3/lib/python3.6/sre_compile.py in compile(p, flags)
#     560     if isstring(p):
#     561         pattern = p
# --> 562         p = sre_parse.parse(p, flags)
#     563     else:
#     564         pattern = None
#
# /home/tophel/anaconda3/lib/python3.6/sre_parse.py in parse(str, flags, pattern)
#     854
#     855     try:
# --> 856         p = _parse_sub(source, pattern, flags & SRE_FLAG_VERBOSE, False)
#     857     except Verbose:
#     858         # the VERBOSE flag was switched on inside the pattern.  to be
#
# /home/tophel/anaconda3/lib/python3.6/sre_parse.py in _parse_sub(source, state, verbose, nested)
#     413     start = source.tell()
#     414     while True:
# --> 415         itemsappend(_parse(source, state, verbose))
#     416         if not sourcematch("|"):
#     417             break
#
# /home/tophel/anaconda3/lib/python3.6/sre_parse.py in _parse(source, state, verbose)
#     764             if not source.match(")"):
#     765                 raise source.error("missing ), unterminated subpattern",
# --> 766                                    source.tell() - start)
#     767             if group is not None:
#     768                 state.closegroup(group, p)
#
# error: missing ), unterminated subpattern at position 29

# %%
df[df['file']==1]
# Out:
#     index                                             syntax  \
# 0       0  [[0, 3, СМИ, NOUN, Animacy=Inan|Case=Nom|Gende...
# 1       1  [[0, 6, inosmi, ADJ, Animacy=Inan|Case=Nom|Gen...
# 2      10  [[0, 5, Обама, NOUN, Animacy=Anim|Case=Nom|Gen...
# 3      11  [[0, 1, C, ADP, Animacy=Inan|Case=Nom|Gender=F...
# 4      12  [[0, 1, А, CONJ, fPOS=CONJ++, 7, cc, а], [2, 1...
# 5      13  [[0, 1, И, CONJ, fPOS=CONJ++, 3, cc, и], [2, 1...
# 6      14  [[0, 5, Таким, DET, Case=Ins|Gender=Masc|Numbe...
# 7      15  [[0, 2, По, ADP, fPOS=ADP++, 2, case, по], [3,...
# 8      16  [[0, 10, Изначально, ADV, Degree=Pos|fPOS=ADV+...
# 9      17  [[0, 2, По, ADP, fPOS=ADP++, 1, case, по], [3,...
# 10     18  [[0, 6, Однако, ADV, Degree=Pos|fPOS=ADV++, 10...
# 11     19  [[0, 1, В, ADP, fPOS=ADP++, 1, case, в], [2, 7...
# 12      2  [[0, 1, 5, NUM, fPOS=NUM++, -1, ROOT, 5], [1, ...
# 13     20  [[0, 1, «, PUNCT, fPOS=PUNCT++,, 1, punct, «\n...
# 14     21  [[0, 12, Беспокойство, NOUN, Animacy=Inan|Case...
# 15     22  [[0, 1, О, ADP, fPOS=ADP++, 2, case, о], [2, 1...
# 16     23  [[0, 7, Издание, NOUN, Animacy=Inan|Case=Nom|G...
# 17     24  [[0, 2, Но, CONJ, fPOS=CONJ++, 6, cc, но], [3,...
# 18     25  [[0, 7, Издание, NOUN, Animacy=Inan|Case=Nom|G...
# 19     26  [[0, 6, Однако, ADV, Degree=Pos|fPOS=ADV++, 12...
# 20     27  [[0, 6, Москва, NOUN, Animacy=Inan|Case=Nom|Ge...
# 21     28  [[0, 5, Главы, NOUN, Animacy=Anim|Case=Nom|Gen...
# 22     29  [[0, 8, Очевидно, ADJ, Degree=Pos|Gender=Neut|...
# 23      3  [[0, 5, Зачем, ADV, Degree=Pos|fPOS=ADV++, 2, ...
# 24     30  [[0, 2, До, ADP, fPOS=ADP++, 3, case, до], [3,...
# 25     31  [[0, 1, В, ADP, fPOS=ADP++, 2, case, в], [2, 7...
# 26     32  [[0, 12, Руководители, NOUN, Animacy=Anim|Case...
# 27     33  [[0, 3, При, ADP, fPOS=ADP++, 1, case, при], [...
# 28     34  [[0, 1, С, ADP, fPOS=ADP++, 2, case, с], [2, 8...
# 29     35  [[0, 1, С, ADP, fPOS=ADP++, 2, case, с], [2, 6...
# 30     36  [[0, 5, Среди, ADP, fPOS=ADP++, 1, case, среди...
# 31     37  [[0, 1, И, CONJ, fPOS=CONJ++, 4, cc, и], [2, 8...
# 32     38  [[0, 6, Keyhan, NOUN, Animacy=Inan|Case=Nom|Ge...
# 33     39  [[0, 8, Согласно, ADP, fPOS=ADP++, 2, case, со...
# 34      4  [[0, 5, 30.04, NUM, fPOS=NUM++, 2, nummod, 30....
# 35     40  [[0, 7, Аятолла, NOUN, Animacy=Inan|Case=Gen|G...
# 36     41  [[0, 1, А, CONJ, fPOS=CONJ++, 9, cc, а], [2, 3...
# 37     42  [[0, 1, В, ADP, fPOS=ADP++, 1, case, в], [2, 1...
# 38     43  [[0, 15, Инспирированные, VERB, Aspect=Perf|Ca...
# 39     44  [[0, 1, В, ADP, fPOS=ADP++, 1, case, в], [2, 7...
# 40     45  [[0, 3, Это, NOUN, Animacy=Inan|Case=Nom|Gende...
# 41     46  [[0, 1, В, ADP, fPOS=ADP++, 1, case, в], [2, 7...
# 42     47  [[0, 8, Владимир, NOUN, Animacy=Anim|Case=Nom|...
# 43     48  [[0, 3, Это, NOUN, Animacy=Inan|Case=Nom|Gende...
# 44     49  [[0, 11, Кандидатуру, NOUN, Animacy=Inan|Case=...
# 45      5  [[0, 8, Согласно, ADP, fPOS=ADP++, 1, case, со...
# 46     50  [[0, 9, Последний, ADJ, Case=Nom|Degree=Pos|Ge...
# 47     51  [[0, 6, Однако, ADV, Degree=Pos|fPOS=ADV++, 11...
# 48     52  [[0, 7, Тегеран, NOUN, Animacy=Inan|Case=Nom|G...
# 49     53  [[0, 4, Иран, NOUN, Animacy=Inan|Case=Nom|Gend...
# 50     54                                                 []
# 51      6  [[0, 6, Однако, ADV, Degree=Pos|fPOS=ADV++, 6,...
# 52      7  [[0, 8, Примерно, ADV, Degree=Pos|fPOS=ADV++, ...
# 53      8  [[0, 6, Почему, ADV, Degree=Pos|fPOS=ADV++, 19...
# 54      9  [[0, 7, Следует, VERB, Aspect=Imp|Mood=Ind|Num...
#
#                                                  text  file
# 0   СМИ Ирана: Финляндия не хочет вступать в НАТО ...     1
# 1                                           inosmi.ru     1
# 2   Обама крайне нуждается в любых шагах, которые ...     1
# 3   C другой стороны, сирийская армия при поддержк...     1
# 4   А контроль над этими провинциями — это господс...     1
# 5   И правительственная армия объявила о начале бо...     1
# 6   Таким образом, напрашивается вывод: если эти о...     1
# 7   По его мнению, на самом деле цель Белого дома ...     1
# 8   Изначально иранские СМИ сообщали об отказе Мос...     1
# 9   По соглашениям США и РФ, боевые действия в окр...     1
# 10  Однако в российском Минобороны, как и в МИДе, ...     1
# 11  В ответ на просьбы Джона Керри, который накану...     1
# 12                                         5-го, 2016     1
# 13  «Мы не можем оказывать давление на администрац...     1
# 14  Беспокойство США очевидно: тот, кто окажется п...     1
# 15  О категорическом отказе России влиять на сирий...     1
# 16  Издание, со ссылкой на срочное сообщение канал...     1
# 17  Но через пару дней тот же портал Javan (3.05) ...     1
# 18  Издание отметило, что, действительно, по мере ...     1
# 19  Однако после визита в Москву спецпосланника ОО...     1
# 20  Москва и Пекин осудили инициативы США по разме...     1
# 21  Главы дипведомств РФ и КНР на совместной пресс...     1
# 22  Очевидно, что Россия и КНР считают планы США п...     1
# 23  Зачем американцам понадобилось перебросить 250...     1
# 24  До 4 тысяч военнослужащих намерен сосредоточит...     1
# 25  В общей сложности дополнительные силы НАТО на ...     1
# 26  Руководители НАТО подчеркивают, что будут дейс...     1
# 27  При этом Москва неоднократно подчеркивала, что...     1
# 28  С другой стороны, альянс старается воплотить в...     1
# 29  С этой целью НАТО старается завлечь к себе те ...     1
# 30  Среди них особое место занимает Финляндия, для...     1
# 31  И сейчас страна не проявляет особой склонности...     1
# 32  Keyhan сообщает о докладе, подготовленном для ...     1
# 33  Согласно последним данным соцопросов, добавила...     1
# 34        30.04) Алиреза Резахах (Alireza Rezakhah).      1
# 35  Аятолла Али Хаменеи, давая оценку ирано-корейс...     1
# 36  А в целом американское влияние на политику люб...     1
# 37  В качестве примера Али Хаменеи привел ситуацию...     1
# 38  Инспирированные США и поддержанные Европой «ре...     1
# 39  В итоге перспектива военного противостояния с ...     1
# 40  Это может стать реальностью, последствия котор...     1
# 41  В канун Первомая в России произведены радикаль...     1
# 42  Владимир Путин отправил в отставку сразу семь ...     1
# 43  Это самая крупная перестановка в российских си...     1
# 44  Кандидатуру республиканца Дональда Трампа на п...     1
# 45  Согласно заявлениям из Пентагона, цель США — с...     1
# 46  Последний, отметил Алеми, наиболее откровенно ...     1
# 47  Однако, полагает Алеми, подобное замечание гла...     1
# 48  Тегеран и Дамаск — это союзники в политическом...     1
# 49  Иран и Сирия входят в одну группу квалификацио...     1
# 50                                                        1
# 51  Однако в Дамаске действия Вашингтона резко осу...     1
# 52  Примерно в аналогичном ключе высказалась и Мос...     1
# 53  Почему же и в Москве и Дамаске, которые также ...     1
# 54  Следует напомнить, указывает он, что Сирия ока...     1

# %%
pd.DataFrame(opinions)
# Out:
#                     0                 1  2  \
# 0                 сми              нато -1
# 1                 сми            россия -2
# 2                иран              нато -1
# 3                иран            россия -2
# 4           финляндия              нато -1
# 5           финляндия            россия -2
# 6                нато            россия -1
# 7               сирия          румийлан  0
# 8               сирия          Khorasan  0
# 9             америка             сирия  0
# 10              сирия                ес  0
# 11           румийлан          Khorasan  0
# 12                ири          румийлан  0
# 13            америка          румийлан  0
# 14                 ес          румийлан  0
# 15                ири          Khorasan  0
# 16            америка          Khorasan  0
# 17                 ес          Khorasan  0
# 18            америка               ири  0
# 19                ири                ес  0
# 20            америка                ес  0
# 21           пентагон               сша  0
# 22           пентагон              игил  1
# 23           пентагон             ракка  2
# 24           пентагон                ес  1
# 25                сша              игил  1
# 26                сша             ракка  2
# 27                сша                ес  1
# 28               игил             ракка  1
# 29               игил                ес  0
# ..                ...               ... ..
# 490             алеми                ес -1
# 491             трамп                ес  0
# 492             алеми             трамп -1
# 493               мид               сша  1
# 494                ес               сша  1
# 495             алеми               сша  1
# 496             трамп               сша  1
# 497               мид                ес  0
# 498             алеми               мид  0
# 499               мид             трамп  0
# 500             алеми                ес  0
# 501                ес             трамп  0
# 502             алеми             трамп  0
# 503            дамаск            Keyhan  2
# 504            дамаск                ес  1
# 505                ес            Keyhan  1
# 506           тегеран            Keyhan  2
# 507           тегеран                ес  1
# 508              иран            россия  0
# 509              иран  хоссама аль-саед -1
# 510              иран     карлуш кейруш -1
# 511             сирия            россия  0
# 512               ири            россия  0
# 513            россия  хоссама аль-саед -1
# 514            россия     карлуш кейруш -1
# 515             сирия  хоссама аль-саед -1
# 516             сирия     карлуш кейруш -1
# 517               ири  хоссама аль-саед -1
# 518               ири     карлуш кейруш -1
# 519  хоссама аль-саед     карлуш кейруш  0
#
#                                                      3
# 0    СМИ Ирана: Финляндия не хочет вступать в НАТО ...
# 1    СМИ Ирана: Финляндия не хочет вступать в НАТО ...
# 2    СМИ Ирана: Финляндия не хочет вступать в НАТО ...
# 3    СМИ Ирана: Финляндия не хочет вступать в НАТО ...
# 4    СМИ Ирана: Финляндия не хочет вступать в НАТО ...
# 5    СМИ Ирана: Финляндия не хочет вступать в НАТО ...
# 6    СМИ Ирана: Финляндия не хочет вступать в НАТО ...
# 7    Зачем американцам понадобилось перебросить 250...
# 8    Зачем американцам понадобилось перебросить 250...
# 9    Зачем американцам понадобилось перебросить 250...
# 10   Зачем американцам понадобилось перебросить 250...
# 11   Зачем американцам понадобилось перебросить 250...
# 12   Зачем американцам понадобилось перебросить 250...
# 13   Зачем американцам понадобилось перебросить 250...
# 14   Зачем американцам понадобилось перебросить 250...
# 15   Зачем американцам понадобилось перебросить 250...
# 16   Зачем американцам понадобилось перебросить 250...
# 17   Зачем американцам понадобилось перебросить 250...
# 18   Зачем американцам понадобилось перебросить 250...
# 19   Зачем американцам понадобилось перебросить 250...
# 20   Зачем американцам понадобилось перебросить 250...
# 21   Согласно заявлениям из Пентагона, цель США — с...
# 22   Согласно заявлениям из Пентагона, цель США — с...
# 23   Согласно заявлениям из Пентагона, цель США — с...
# 24   Согласно заявлениям из Пентагона, цель США — с...
# 25   Согласно заявлениям из Пентагона, цель США — с...
# 26   Согласно заявлениям из Пентагона, цель США — с...
# 27   Согласно заявлениям из Пентагона, цель США — с...
# 28   Согласно заявлениям из Пентагона, цель США — с...
# 29   Согласно заявлениям из Пентагона, цель США — с...
# ..                                                 ...
# 490  Последний, отметил Алеми, наиболее откровенно ...
# 491  Последний, отметил Алеми, наиболее откровенно ...
# 492  Последний, отметил Алеми, наиболее откровенно ...
# 493  Однако, полагает Алеми, подобное замечание гла...
# 494  Однако, полагает Алеми, подобное замечание гла...
# 495  Однако, полагает Алеми, подобное замечание гла...
# 496  Однако, полагает Алеми, подобное замечание гла...
# 497  Однако, полагает Алеми, подобное замечание гла...
# 498  Однако, полагает Алеми, подобное замечание гла...
# 499  Однако, полагает Алеми, подобное замечание гла...
# 500  Однако, полагает Алеми, подобное замечание гла...
# 501  Однако, полагает Алеми, подобное замечание гла...
# 502  Однако, полагает Алеми, подобное замечание гла...
# 503  Тегеран и Дамаск — это союзники в политическом...
# 504  Тегеран и Дамаск — это союзники в политическом...
# 505  Тегеран и Дамаск — это союзники в политическом...
# 506  Тегеран и Дамаск — это союзники в политическом...
# 507  Тегеран и Дамаск — это союзники в политическом...
# 508  Иран и Сирия входят в одну группу квалификацио...
# 509  Иран и Сирия входят в одну группу квалификацио...
# 510  Иран и Сирия входят в одну группу квалификацио...
# 511  Иран и Сирия входят в одну группу квалификацио...
# 512  Иран и Сирия входят в одну группу квалификацио...
# 513  Иран и Сирия входят в одну группу квалификацио...
# 514  Иран и Сирия входят в одну группу квалификацио...
# 515  Иран и Сирия входят в одну группу квалификацио...
# 516  Иран и Сирия входят в одну группу квалификацио...
# 517  Иран и Сирия входят в одну группу квалификацио...
# 518  Иран и Сирия входят в одну группу квалификацио...
# 519  Иран и Сирия входят в одну группу квалификацио...
#
# [520 rows x 4 columns]
