# %%
import pandas as pd
from tqdm import tqdm_notebook as tqdm

# %%
from syntaxnet_wrapper import PipelineSyntaxNet
host = 'localhost'
port = 8111 # E.g.
proc = PipelineSyntaxNet(host, port)

def get_syntax(line,proc):
    def res_to_array(result):
        res=[]
        for sent in result:
            resent=[]
            for word in sent:
                resent.append(str(word))
            res.append(resent)
        return(res)
    result = proc.process(line)
    return(res_to_array(result))

# %%
#seq
for i in tqdm(range(1,46)):
    if(i in [9,22,26]): continue
    df = pd.read_csv("Texts/art{}.txt".format(i),delimiter='\n')
    df.columns=['text']
    df['text'] = df.text.str.replace('{Author, Unknown} ',"")
    tqdm.pandas(desc="extracting syntax")
    df['syntax'] = df['text'].progress_apply(lambda x:get_syntax(x.decode('utf8'),proc))
    df.to_json('Texts/art{}syn.json'.format(i))

# %%
df = pd.DataFrame()
for i in tqdm(range(1,46)):
    if(i in [9,22,26]): continue
    df = pd.concat([df,pd.read_json('Texts/art{}syn.json'.format(i))])
# Out:
#   0%|          | 0/45 [00:00<?, ?it/s]
#
#  31%|███       | 14/45 [00:00<00:00, 133.32it/s]
#
#  80%|████████  | 36/45 [00:00<00:00, 149.60it/s]
#
# 100%|██████████| 45/45 [00:00<00:00, 162.13it/s]

# %%
df
# Out:
#                                                syntax  \
# 0   [[0 3 | word_form: СМИ pos_tag: NOUN morph: An...
# 1   [[0 6 | word_form: inosmi pos_tag: ADJ morph: ...
# 10  [[0 5 | word_form: Обама pos_tag: NOUN morph: ...
# 11  [[0 1 | word_form: C pos_tag: ADP morph: Anima...
# 12  [[0 1 | word_form: А pos_tag: CONJ morph: fPOS...
# 13  [[0 1 | word_form: И pos_tag: CONJ morph: fPOS...
# 14  [[0 5 | word_form: Таким pos_tag: DET morph: C...
# 15  [[0 2 | word_form: По pos_tag: ADP morph: fPOS...
# 16  [[0 10 | word_form: Изначально pos_tag: ADV mo...
# 17  [[0 2 | word_form: По pos_tag: ADP morph: fPOS...
# 18  [[0 6 | word_form: Однако pos_tag: ADV morph: ...
# 19  [[0 1 | word_form: В pos_tag: ADP morph: fPOS=...
# 2   [[0 1 | word_form: 5 pos_tag: NUM morph: fPOS=...
# 20  [[0 1 | word_form: « pos_tag: PUNCT morph: fPO...
# 21  [[0 12 | word_form: Беспокойство pos_tag: NOUN...
# 22  [[0 1 | word_form: О pos_tag: ADP morph: fPOS=...
# 23  [[0 7 | word_form: Издание pos_tag: NOUN morph...
# 24  [[0 2 | word_form: Но pos_tag: CONJ morph: fPO...
# 25  [[0 7 | word_form: Издание pos_tag: NOUN morph...
# 26  [[0 6 | word_form: Однако pos_tag: ADV morph: ...
# 27  [[0 6 | word_form: Москва pos_tag: NOUN morph:...
# 28  [[0 5 | word_form: Главы pos_tag: NOUN morph: ...
# 29  [[0 8 | word_form: Очевидно pos_tag: ADJ morph...
# 3   [[0 5 | word_form: Зачем pos_tag: ADV morph: D...
# 30  [[0 2 | word_form: До pos_tag: ADP morph: fPOS...
# 31  [[0 1 | word_form: В pos_tag: ADP morph: fPOS=...
# 32  [[0 12 | word_form: Руководители pos_tag: NOUN...
# 33  [[0 3 | word_form: При pos_tag: ADP morph: fPO...
# 34  [[0 1 | word_form: С pos_tag: ADP morph: fPOS=...
# 35  [[0 1 | word_form: С pos_tag: ADP morph: fPOS=...
# ..                                                ...
# 27  [[0 3 | word_form: Тем pos_tag: NOUN morph: An...
# 28  [[0 2 | word_form: Но pos_tag: CONJ morph: fPO...
# 29  [[0 5 | word_form: После pos_tag: ADP morph: f...
# 3   [[0 2 | word_form: По pos_tag: ADP morph: fPOS...
# 30  [[0 3 | word_form: Тем pos_tag: DET morph: Cas...
# 31  [[0 6 | word_form: Однако pos_tag: ADV morph: ...
# 32  [[0 1 | word_form: А pos_tag: CONJ morph: fPOS...
# 33  [[0 1 | word_form: И pos_tag: CONJ morph: fPOS...
# 34  [[0 2 | word_form: По pos_tag: ADP morph: fPOS...
# 35  [[0 3 | word_form: При pos_tag: ADP morph: fPO...
# 36  [[0 1 | word_form: И pos_tag: CONJ morph: fPOS...
# 37  [[0 6 | word_form: Кремль pos_tag: NOUN morph:...
# 38  [[0 5 | word_form: Когда pos_tag: SCONJ morph:...
# 39  [[0 6 | word_form: Однако pos_tag: ADV morph: ...
# 4   [[0 10 | word_form: Штайнмайер pos_tag: NOUN m...
# 40  [[0 1 | word_form: С pos_tag: ADP morph: fPOS=...
# 41  [[0 3 | word_form: Тот pos_tag: ADJ morph: Cas...
# 42  [[0 1 | word_form: И pos_tag: CONJ morph: fPOS...
# 43  [[0 5 | word_form: После pos_tag: ADP morph: f...
# 44  [[0 1 | word_form: И pos_tag: CONJ morph: fPOS...
# 45  [[0 2 | word_form: Ни pos_tag: PART morph: fPO...
# 46  [[0 1 | word_form: В pos_tag: ADP morph: fPOS=...
# 47  [[0 2 | word_form: Но pos_tag: CONJ morph: fPO...
# 48  [[0 5 | word_form: Время pos_tag: NOUN morph: ...
# 49                                                 []
# 5   [[0 7 | word_form: Конечно pos_tag: ADV morph:...
# 6   [[0 3 | word_form: Для pos_tag: ADP morph: fPO...
# 7   [[0 9 | word_form: Вертолеты pos_tag: NOUN mor...
# 8   [[0 1 | word_form: И pos_tag: CONJ morph: fPOS...
# 9   [[0 6 | word_form: Однако pos_tag: ADV morph: ...
#
#                                                  text
# 0   СМИ Ирана: Финляндия не хочет вступать в НАТО ...
# 1                                           inosmi.ru
# 10  Обама крайне нуждается в любых шагах, которые ...
# 11  C другой стороны, сирийская армия при поддержк...
# 12  А контроль над этими провинциями — это господс...
# 13  И правительственная армия объявила о начале бо...
# 14  Таким образом, напрашивается вывод: если эти о...
# 15  По его мнению, на самом деле цель Белого дома ...
# 16  Изначально иранские СМИ сообщали об отказе Мос...
# 17  По соглашениям США и РФ, боевые действия в окр...
# 18  Однако в российском Минобороны, как и в МИДе, ...
# 19  В ответ на просьбы Джона Керри, который накану...
# 2                                          5-го, 2016
# 20  «Мы не можем оказывать давление на администрац...
# 21  Беспокойство США очевидно: тот, кто окажется п...
# 22  О категорическом отказе России влиять на сирий...
# 23  Издание, со ссылкой на срочное сообщение канал...
# 24  Но через пару дней тот же портал Javan (3.05) ...
# 25  Издание отметило, что, действительно, по мере ...
# 26  Однако после визита в Москву спецпосланника ОО...
# 27  Москва и Пекин осудили инициативы США по разме...
# 28  Главы дипведомств РФ и КНР на совместной пресс...
# 29  Очевидно, что Россия и КНР считают планы США п...
# 3   Зачем американцам понадобилось перебросить 250...
# 30  До 4 тысяч военнослужащих намерен сосредоточит...
# 31  В общей сложности дополнительные силы НАТО на ...
# 32  Руководители НАТО подчеркивают, что будут дейс...
# 33  При этом Москва неоднократно подчеркивала, что...
# 34  С другой стороны, альянс старается воплотить в...
# 35  С этой целью НАТО старается завлечь к себе те ...
# ..                                                ...
# 27  Тем самым он устанавливает связь с докладом Ар...
# 28  Но где же в практической политике НАТО находит...
# 29  После аннексии Крыма опрометчивым образом был ...
# 3   По его словам, нам не следует с помощью «громк...
# 30  Тем временем одно заседание этого совета уже с...
# 31  Однако отдающие холодом переговоры на уровне п...
# 32  А где же смелые дипломатические инициативы, ко...
# 33  И где новое двойное решение, которой вновь сде...
# 34  По крайней мере, следует изучить вопрос о том,...
# 35  При этом в руках Запада есть козырь: он может ...
# 36  И прежде чем вы начнете обвинять меня в том, ч...
# 37  Кремль, кто бы там не правил, никогда не верне...
# 38  Когда Путин его аннексировал, формально он нар...
# 39  Однако в его пользу говорят два вещи: история ...
# 4   Штайнмайер использовал сильные выражения, но о...
# 40  С того момента, как Екатерина Великая включила...
# 41  Тот факт, что украинец Хрущев в 1954 году, как...
# 42  И не случайно Путин стал проявлять беспокойств...
# 43  После революции Майдана русские столкнулись с ...
# 44  И как только представилась возможность сохрани...
# 45  Ни один кремлевский правитель никогда больше н...
# 46  В таком случае было бы лучше попытаться, стисн...
# 47  Но к этому Франк-Вальтер Штайнмайер еще не гот...
# 48                    Время для этого еще не настало.
# 49
# 5   Конечно же, необходимо, чтобы европейские член...
# 6   Для этого необходимо также смириться с увеличе...
# 7   Вертолеты, которые не летают, артиллерийские о...
# 8   И, несомненно, имеет смыл за счет минимального...
# 9   Однако мы должны избегать того, чтобы делать и...
#
# [2204 rows x 2 columns]
