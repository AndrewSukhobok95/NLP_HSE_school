# %% [markdown]
# # NLP HSE School

# %%
from pymystem3 import Mystem
import pandas as pd
import re
m=Mystem()
pd.set_option('display.width', 1000)
pd.set_option('display.expand_frame_repr', False)

# %%
sentilex = pd.read_csv('RuSentiLex2017_revised_2utf.txt',
                       names=['word','part','initial','sentiment','source','amb1','amb2'],
                       skiprows=20,skipinitialspace=True,index_col=2)
sentilex['sentiment'] = sentilex['sentiment'].map({'negative':-1,'positive':1,'neutral':0,'positive/negative':0})

# %%
vocab = sentilex.to_dict(orient='index')

# %%
def read_file(n):
    file = pd.read_csv('Texts/art{}.txt'.format(n),sep='\n',names=['lines'])
    file.lines = file.lines.str.replace("{Author, Unknown} ","")
    
    ent_df = pd.read_csv('Texts/art{}.ann'.format(n),sep='\t',names=['ind','descr','ne'],header=None)
    ent_df['initial'] = ent_df['ne'].apply(lambda x: ("".join(m.lemmatize(x.lower()))).replace('\n',""))
    ent_df = ent_df.set_index(ent_df['ne'])
    syn_df = pd.read_json('Texts/art{}syn.json'.format(n))

    syn_df = syn_df.reset_index()
    def get_struct_data(x):
        sentl =[]
        pars=[]
        for text in x:
            for sent in text:
                sentl = sent.split(' ')
                to_app = [sentl[i] for i in range(len(sentl)) if i in([0,1,4,6,8,10,12])]
                to_app.append(m.lemmatize(to_app[2])[0])
                pars.append(to_app)
        return(pars)

    syn_df['syntax'] = syn_df['syntax'].apply(get_struct_data)
    
    syn_df['index']=syn_df['index'] +1
    file = file.reset_index().merge(syn_df)
    return(file.drop('text',1), ent_df.to_dict(orient='index'))

# %%
# получение полярностей
from sentiframes_proc import find_polar
table = pd.read_csv('sentiframes_df.csv')

lst = [['31', '42', 'бомбит', 'VERB', 'Aspect=Imperf|VerbForm=Inf|fPOS=VERB++', '2', 'nsubj', 'бомбить'],       
       ['78', '83', 'Сирии', 'NOUN', 'Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing|fPOS=NOUN++', '10', 'dobj', 'сирия'],
       ['107', '115', 'Румийлан', 'NOUN', 'Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing|fPOS=NOUN++', '15', 'appos', 'румийлан']]


find_polar(lst[0], lst[1], lst[2])
# Out:
# [('румийлан', 'сирия', 'neg'), ('сирия', 'румийлан', 'neg')]

# %%
text_lines, ent_dict = read_file(1)

# %%
#получение данных из синтаксиса
def get_mutual_node(syntax,ent1,ent1pos,ent2,ent2pos):
    
    def get_node(e,p):
        
        e = e.split(" ")[0].split("-")[0]
        ent_dict = dict()
        for i in range(len(syntax)):
            if(syntax[i][2]==e):
                
                ent_dict[abs(int(syntax[i][1])-p)]=i
        
        return ent_dict[sorted(ent_dict)[0]]
    def get_route(i):
        route = list()
        for _ in range(len(syntax)):
            h=int(syntax[i][5])
            if(h ==-1): return route
            route.append(syntax[h])
            i=h
    ent_node1 = get_node(ent1,ent1pos)
    ent_node2 = get_node(ent2,ent2pos)
    
    route1= get_route(ent_node1)[::-1]
    route2= get_route(ent_node2)[::-1]
    if(len(route1)==0): return syntax[ent_node1],syntax[ent_node1],syntax[ent_node2]
    if(len(route2)==0): return syntax[ent_node2],syntax[ent_node1],syntax[ent_node2]

    for i in range(min(len(route1),len(route2))):
        
        if(route1[i][0]==route2[i][0]): obj=route1[i]
        else: break
    
    
    return [obj,syntax[ent_node1],syntax[ent_node2]]

# %%
import re
import nltk
from nltk import ngrams as ng
def get_sent_list(lemmas):
    sent_list = []
    string = "".join(lemmas)
    for i in reversed(range(1,min(11,len(lemmas)))):
        ngrams = ng(lemmas,i)
        for ngram in ngrams:
            subs = "".join(list(ngram))
            if(subs in vocab): 
                sent_list.append(vocab[subs]['sentiment'])
                lemmas = m.lemmatize(string.replace(subs,""))
    return sent_list

def sentiment_extraction(x,ent_dict):
    line = x['lines']
    syntax = x['syntax']
    ne_list = []
    for ne in ent_dict.keys():
        regex= re.compile(r"\b{}\b".format(re.escape(ne)),flags=re.UNICODE)
        for pos in ([m.start(0) for m in re.finditer(regex, line)]):
            ne_list.append((ne,pos))
    ne_pairs  = [(ne1,ne2) for ne1 in ne_list for ne2 in ne_list if ne1 != ne2]
    
    mutuals = list()
    polarities = list()
    for ((ne1, ne1_pos), (ne2,ne2_pos)) in ne_pairs:
        mut = get_mutual_node(syntax,ne1, ne1_pos, ne2, ne2_pos)
        mutuals.append(mut)
        plarities = find_polar(mut[0], mut[1], mut[2])
                   
    x['mutuals']=mutuals
    x['polarities']=polarities
    
    
    x['ne_pairs'] = ne_pairs
    
    x['ne_substrings'] = [(ne1,ne2,line[pos1+len(ne1):pos2]) for (ne1,pos1),(ne2,pos2) in ne_pairs if pos2>pos1+10]
    
    sent_list = list()
    for ne1,ne2,subs in x['ne_substrings']:
        sent_list.append((ne1,ne2,get_sent_list(m.lemmatize(subs))))
    x['sent_list'] = sent_list
    
    return(x)

# %%
#считывание и извлечение
text_lines, ent_dict = read_file(1)


text_lines = text_lines.apply(lambda x:sentiment_extraction(x,ent_dict),axis=1)
text_lines
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-cf1a884265e3> in <module>()
#       3
#       4
# ----> 5 text_lines = text_lines.apply(lambda x:sentiment_extraction(x,ent_dict),axis=1)
#       6 text_lines
#
# /home/tophel/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4150                     if reduce is None:
#    4151                         reduce = True
# -> 4152                     return self._apply_standard(f, axis, reduce=reduce)
#    4153             else:
#    4154                 return self._apply_broadcast(f, axis)
#
# /home/tophel/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4246             try:
#    4247                 for i, v in enumerate(series_gen):
# -> 4248                     results[i] = func(v)
#    4249                     keys.append(v.name)
#    4250             except Exception as e:
#
# <ipython-input-33-cf1a884265e3> in <lambda>(x)
#       3
#       4
# ----> 5 text_lines = text_lines.apply(lambda x:sentiment_extraction(x,ent_dict),axis=1)
#       6 text_lines
#
# <ipython-input-32-84fd0c5961c8> in sentiment_extraction(x, ent_dict)
#      29         mut = get_mutual_node(syntax,ne1, ne1_pos, ne2, ne2_pos)
#      30         mutuals.append(mut)
# ---> 31         plarities = find_polar(mut[0], mut[1], x[2])
#      32
#      33     x['mutuals']=mutuals
#
# /home/tophel/NLP_HSE_school/sentiframes_proc.py in find_polar(parent, child1, child2)
#      44     lst1 += child1[4].split('|')
#      45     lst2 = [child2[3]]
# ---> 46     lst2 += child2[4].split('|')
#      47     lemma_parent = parent[len(parent)-1]
#      48     lemma_child1= child1[len(child1)-1]
#
# AttributeError: ("'list' object has no attribute 'split'", 'occurred at index 0')

# %%
def get_summed_over_sent(sent_list):
    sdict = dict()
    for ne1,ne2,slist in sent_list:
        if (ne1,ne2) in sdict:sdict[(ent_dict[ne1]['initial'],ent_dict[ne2]['initial'])]+=sum(slist)
        else: sdict[(ent_dict[ne1]['initial'],ent_dict[ne2]['initial'])]=sum(slist) 
    return sdict
text_lines['summed'] =  text_lines['sent_list'].apply(get_summed_over_sent)
text_lines['summed']

# %%
opinions = dict()
def get_summed(sent_list):
        for k in sent_list.keys():
            if k in opinions : opinions[k]+=sent_list[k]
            else: opinions[k]=sent_list[k]
            
_ = text_lines['summed'].apply(get_summed)
df = pd.DataFrame([(ne1,ne2,opinions[(ne1,ne2)]) for (ne1,ne2) in opinions.keys()],columns=['ne1','ne2','sent'])
df

# %%
df['sent'] = df['sent'].apply(lambda x: 'negative' if x<0 else ('positive' if x>0 else None))

# %%
df[~df['sent'].isnull()].to_csv('Texts/1.csv',index=False,header=False)

# %%
#считывание и извлечение
from tqdm import tqdm
for i in tqdm(range(1,46)):
    if(i in [9,22,26,18,25,35]): continue
    print (i)
    text_lines, ent_dict = read_file(i)

    text_lines = text_lines.apply(lambda x:sentiment_extraction(x,ent_dict),axis=1)[['ne_pairs','ne_substrings','sent_list']]
    opinions = dict()
    text_lines['summed'] =  text_lines['sent_list'].apply(get_summed_over_sent)
    _ = text_lines['summed'].apply(get_summed)
    df = pd.DataFrame([(ne1,ne2,opinions[(ne1,ne2)]) for (ne1,ne2) in opinions.keys()],columns=['ne1','ne2','sent'])
    df['sent'] = df['sent'].apply(lambda x: 'negative' if x<0 else ('positive' if x>0 else None))
    df[~df['sent'].isnull()].to_csv('Texts/{}.csv'.format(i),index=False,header=False)

# %%
text_lines
# Out:
#                                              ne_pairs                                      ne_substrings                                          sent_list
# 0   [((СМИ, 0), (Ирана, 4)), ((СМИ, 0), (Финляндия...  [(СМИ, Финляндия,  Ирана: ), (СМИ, НАТО,  Иран...  [(СМИ, Финляндия, []), (СМИ, НАТО, [-1]), (СМИ...
# 1                                                  []                                                 []                                                 []
# 2                                                  []                                                 []                                                 []
# 3   [((Сирии, 78), (Румийлан, 107)), ((Сирии, 78),...  [(Сирии, Румийлан, , к окрестностям города ), ...  [(Сирии, Румийлан, []), (Сирии, Khorasan, []),...
# 4   [((Алиреза Резахах (Alireza Rezakhah, 7), (Рез...                                                 []                                                 []
# 5   [((Пентагона, 23), (США, 39)), ((Пентагона, 23...  [(Пентагона, США, , цель ), (Пентагона, ИГИЛ, ...  [(Пентагона, США, []), (Пентагона, ИГИЛ, [1]),...
# 6   [((Сирии, 103), (Дамаске, 9)), ((Сирии, 103), ...  [(Дамаске, Сирии,  действия Вашингтона резко о...  [(Дамаске, Сирии, [-1, -1]), (Дамаске, Вашингт...
# 7   [((Москва, 43), (Дамаском, 74)), ((Москва, 43)...  [(Москва, Дамаском, , где «несогласованные с )...  [(Москва, Дамаском, []), (Москва, Белого дома,...
# 8   [((Сирии, 71), (США, 157)), ((Сирии, 71), (Дам...  [(Сирии, США, , действия Вашингтона вызвали ст...  [(Сирии, США, [0, 0]), (Сирии, Вашингтона, [])...
# 9   [((ИГ, 224), (Сирия, 37)), ((ИГ, 224), (Обамы,...  [(Сирия, ИГ,  оказалась одним из самых проблем...  [(Сирия, ИГ, [-1, 0, -1, -1, -1, -1, -1]), (Си...
# 10  [((Обама, 0), (Ближнем Востоке, 80)), ((Ближне...  [(Обама, Ближнем Востоке,  крайне нуждается в ...              [(Обама, Ближнем Востоке, [0, 1, 1])]
# 11  [((Ракка, 166), (ИГ, 212)), ((Ракка, 166), (ВК...  [(Ракка, ИГ,  и Дираззур, остающихся пока под ...  [(Ракка, ИГ, []), (ВКС, Ракка, []), (ВКС, ИГ, ...
# 12                                                 []                                                 []                                                 []
# 13                                                 []                                                 []                                                 []
# 14  [((Резахах, 214), (Дамаска, 74)), ((Дамаска, 7...  [(Дамаска, Резахах, , то план американцев по «...                         [(Дамаска, Резахах, [-1])]
# 15  [((Белого дома, 34), (Москве, 191)), ((Белого ...  [(Белого дома, Москве,  предельно проста, — чт...  [(Белого дома, Москве, [-1, -1]), (Белого дома...
# 16  [((СМИ, 20), (Сирии, 76)), ((СМИ, 20), (Москвы...  [(СМИ, Сирии,  сообщали об отказе Москвы «повл...  [(СМИ, Сирии, [-1]), (СМИ, Москвы, [-1]), (СМИ...
# 17  [((США, 15), (Дамаска, 56)), ((США, 15), (РФ, ...  [(США, Дамаска,  и РФ, боевые действия в окрес...            [(США, Дамаска, []), (РФ, Дамаска, [])]
# 18  [((Минобороны, 20), (МИДе, 40)), ((Минобороны,...  [(Минобороны, МИДе, , как и в ), (Минобороны, ...  [(Минобороны, МИДе, []), (Минобороны, Халеба, ...
# 19  [((Вашингтона, 243), (МИДе, 159)), ((Вашингтон...  [(МИДе, Вашингтона,  дали понять, что не готов...  [(МИДе, Вашингтона, [1, 1, 1]), (Джона Керри, ...
# 20  [((РФ, 154), (Асада, 49)), ((РФ, 154), (Алеппо...  [(Асада, РФ, , поскольку борьба за Алеппо — эт...  [(Асада, РФ, [-1]), (Асада, Алеппо, []), (Асад...
# 21  [((США, 13), (Вашингтона, 182)), ((США, 13), (...  [(США, Вашингтона,  очевидно: тот, кто окажетс...  [(США, Вашингтона, [1, -1]), (США, Дамаском, [...
# 22  [((России, 24), (Resalat, 141)), ((Resalat, 14...  [(России, Resalat,  влиять на сирийское руково...                            [(России, Resalat, [])]
# 23  [((Асада, 152), (Алеппо, 209)), ((Асада, 152),...  [(Асада, Алеппо,  давление с целью приостанови...  [(Асада, Алеппо, [-1]), (МИД, Асада, []), (МИД...
# 24  [((Сирии, 114), (Javan, 33)), ((Сирии, 114), (...  [(Javan, Сирии,  (3.05) сообщил о смягчении по...  [(Javan, Сирии, []), (Javan, России, []), (Рос...
# 25  [((Алеппо, 74), (Россия, 98)), ((Россия, 98), ...             [(Алеппо, Россия,  сирийской армией )]                             [(Алеппо, Россия, [])]
# 26  [((Сирии, 51), (РФ, 118)), ((Сирии, 51), (Росс...  [(Сирии, РФ,  Стаффана де Мистуры стало извест...  [(Сирии, РФ, []), (Сирии, Россия, []), (Сирии,...
# 27  [((Khorasan, 209), (США, 34)), ((Khorasan, 209...  [(США, Khorasan,  по размещению на юге Корейск...  [(США, Khorasan, [-1]), (США, Корейского полуо...
# 28  [((Вашингтона, 87), (РФ, 18)), ((Вашингтона, 8...  [(Вашингтона, Корейского полуострова,  как «не...  [(Вашингтона, Корейского полуострова, [-1, 0, ...
# 29  [((США, 41), (Россия, 14)), ((США, 41), (КНР, ...  [(США, Республики Корея,  по размещению компле...  [(США, Республики Корея, []), (Россия, США, []...
# 30  [((России, 84), (Североатлантический альянс, 4...  [(России, Польши, , на территории ), (России, ...  [(России, Польши, []), (России, Балтии, []), (...
# 31  [((НАТО, 38), (США, 106)), ((НАТО, 38), (Велик...  [(НАТО, США,  на востоке Европы составят 4 бат...  [(НАТО, США, []), (НАТО, Великобритания, []), ...
# 32  [((НАТО, 13), (РФ, 83)), ((НАТО, 13), (России,...  [(НАТО, РФ,  подчеркивают, что будут действова...  [(НАТО, РФ, []), (НАТО, России, [1]), (НАТО, H...
# 33  [((НАТО, 108), (Москва, 9)), ((НАТО, 108), (Ро...  [(НАТО, России,  и эскалацию враждебного подхо...  [(НАТО, России, [-1, -1]), (Москва, НАТО, [1])...
# 34                                                 []                                                 []                                                 []
# 35  [((НАТО, 13), (Европы, 72)), ((Европы, 72), (Н...  [(НАТО, Европы,  старается завлечь к себе те н...                               [(НАТО, Европы, [])]
# 36  [((Финляндия, 32), (Россия, 55)), ((Россия, 55...              [(Финляндия, Россия, , для которой )]                          [(Финляндия, Россия, [])]
# 37                                                 []                                                 []                                                 []
# 38  [((НАТО, 210), (Keyhan, 0)), ((НАТО, 210), (Фи...  [(Keyhan, НАТО,  сообщает о докладе, подготовл...  [(Keyhan, НАТО, [1]), (Keyhan, Финляндии, []),...
# 39                                                 []                                                 []                                                 []
# 40  [((США, 205), (Resalat, 219)), ((США, 205), (Р...  [(США, Resalat, , передает ), (Республики Коре...  [(США, Resalat, []), (Республики Корея, США, [...
# 41                                                 []                                                 []                                                 []
# 42  [((Сирии, 122), (Али Хаменеи, 19)), ((Сирии, 1...  [(Сирии, Украины, , а затем из-за ), (Сирии, А...  [(Сирии, Украины, []), (Сирии, Америки, []), (...
# 43  [((США, 16), (России, 148)), ((США, 16), (Евро...  [(США, России,  и поддержанные Европой «револю...  [(США, России, [-1]), (США, Европой, []), (США...
# 44                                                 []                                                 []                                                 []
# 45  [((НАТО, 125), (Resalat, 175)), ((НАТО, 125), ...  [(НАТО, Resalat, , буквально «столбенеть от уж...  [(НАТО, Resalat, [-1]), (НАТО, ИРИ, [0, -1]), ...
# 46  [((Javan, 108), (России, 19)), ((России, 19), ...  [(России, Javan,  произведены радикальные пере...                             [(России, Javan, [0])]
# 47  [((Москва, 188), (Владимир Путин, 0)), ((Москв...  [(Москва, МВД, , а также замглавы ), (Москва, ...  [(Москва, МВД, []), (Москва, Республики Крым, ...
# 48                                                 []                                                 []                                                 []
# 49  [((США, 61), (Resalat, 234)), ((США, 61), (ФРГ...  [(США, Resalat,  видят весьма одиозной европей...  [(США, Resalat, [-1]), (США, ФРГ, [-1]), (США,...
# 50  [((США, 235), (Россия, 226)), ((США, 235), (Ал...  [(Алеми, США, , наиболее откровенно выразил св...  [(Алеми, США, [-1, -1]), (Алеми, Россия, [-1, ...
# 51  [((США, 229), (МИДа, 59)), ((США, 229), (Алеми...  [(МИДа, США,  явно подразумевает критику основ...  [(МИДа, США, [0, 1]), (МИДа, Трампа, [0]), (Ал...
# 52  [((Keyhan, 153), (Тегеран, 0)), ((Keyhan, 153)...  [(Тегеран, Keyhan,  и Дамаск — это союзники в ...  [(Тегеран, Keyhan, [1, 1]), (Дамаск, Keyhan, [...
# 53  [((Ирана, 302), (Сирия, 7)), ((Ирана, 302), (Р...  [(Сирия, Ирана,  входят в одну группу квалифик...  [(Сирия, Ирана, []), (Сирия, России, []), (Сир...
# 54                                                 []                                                 []                                                 []
